# %% [markdown]
# # ACCESSBANK_USSD

# %%
# variables

# Our "database" — normally this would be a real database,
# but a dictionary works fine for a simulation.
#account

# %%
print (accounts)
# Out:
# {'08011122111': {'pin': '1234', 'name': 'Esther Ola', 'balance': 50000.0}, '08022222222': {'pin': '4321', 'name': 'John Doe', 'balance': 15000.0}}

# %%
BANK_NAME = "AccessBank"
USSD_CODE = "*950#"

print (BANK_NAME)
print (USSD_CODE)
# Out:
# AccessBank
# *950#

# %%
type ("AccessBank")
type ("*950#")
# Out:
# str

# %%
# FUNCTIONS
# Each menu action is its own function — this keeps the code
# organized and makes each piece easy to test on its own.

# %%
def display_main_menu():
    """Print the main USSD menu."""
    print(f"\n{BANK_NAME} {USSD_CODE}")
    print("1. Check Balance")
    print("2. Transfer Money")
    print("3. Buy Airtime")
    print("4. Change PIN")
    print("0. Exit")
